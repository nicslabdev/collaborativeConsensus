# %%
## Extract statistics for A1 E2 attacks.

# %%
import re
from collections import defaultdict
import numpy as np  # For efficient column-wise mean calculation

# Extract recalls for coordinators
def extract_numbers_by_coordinator(filename):
    data = defaultdict(list)  # Dictionary to store numbers per coordinator
    pattern = r"Split \d+: Recall\s+Coordinator\s+(\d+) => ([\d\.]+)"
    
    with open(filename, 'r') as file:
        for line in file:
            match = re.search(pattern, line)
            if match:
                coordinator = int(match.group(1))  # Extract Coordinator number
                value = float(match.group(2))      # Extract floating-point value
                data[coordinator].append(value)

    return data
def calculate_means(data):
    means = {coord: sum(values) / len(values) for coord, values in data.items() if values != 0}
    return means

            # Extract recalls for coordinators voting#
def extract_numbers_by_coordinator_voting(filename):
    data = defaultdict(list)  # Dictionary to store numbers per coordinator
    pattern = r"Split [0-4]?[0-9]: Recall\s+Coordinator\s+(\d+) => ([\d\.]+)"
    
    with open(filename, 'r') as file:
        for line in file:
            match = re.search(pattern, line)
            if match:
                coordinator = int(match.group(1))  # Extract Coordinator number
                value = float(match.group(2))      # Extract floating-point value
                data[coordinator].append(value)
    return data

# Extract recalls from models
def extract_numbers_by_coordinator_models(filename):
    data = defaultdict(list)  # Dictionary to store lists of values per coordinator
    pattern = r"Split \d+: Recall\s+Models\s+Coordinator\s+(\d+) => \[([\d\.,\s]+)\]"

    with open(filename, 'r') as file:
        for line in file:
            match = re.search(pattern, line)
            if match:
                coordinator = int(match.group(1))  # Extract Coordinator number
                values = list(map(float, match.group(2).split(',')))  # Convert list elements to floats
                data[coordinator].append(values)
    return data

def calculate_column_means(data):
    means = {}

    for coordinator, lists in data.items():
        # Transpose list of lists to group values by column
        num_columns = len(lists[0])  # Assuming all rows have the same number of columns
        column_sums = [0] * num_columns
        column_counts = [0] * num_columns

        for row in lists:
            for i, value in enumerate(row):
                if value != 0:  # Ignore zeros
                    column_sums[i] += value
                    column_counts[i] += 1

        # Compute mean for each column (avoid division by zero)
        column_means = [
            (column_sums[i] / column_counts[i]) if column_counts[i] > 0 else 0
            for i in range(num_columns)
        ]

        means[coordinator] = column_means  # Store results

    return means
    
            # Extract recalls for coordinators models voting#
def extract_numbers_by_coordinator_models_voting(filename):
    data = defaultdict(list)  # Dictionary to store lists of values per coordinator
    pattern = r"Split [0-4]?[0-9]: Recall\s+Models\s+Coordinator\s+(\d+) => \[([\d\.,\s]+)\]"

    with open(filename, 'r') as file:
        for line in file:
            match = re.search(pattern, line)
            if match:
                coordinator = int(match.group(1))  # Extract Coordinator number
                values = list(map(float, match.group(2).split(',')))  # Convert list elements to floats
                data[coordinator].append(values)
    return data

def calculate_overall_column_mean(mean_values):
    num_columns = len(next(iter(mean_values.values())))  # Get number of columns from first coordinator
    overall_means = []

    for col in range(num_columns):
        column_values = [means[col] for means in mean_values.values() if means[col] != 0]  # Ignore 0s
        mean_value = sum(column_values) / len(column_values) if column_values else 0  # Avoid division by zero
        overall_means.append(mean_value)

    return overall_means

# %%
# Recall results for A1, E2 without attack - All 

print("Results for coordinators Analysis 1, Experiment 2 - Without attack")
filename_A1E2 = "nohup_mainBoth_SameDataset_v2_getrecall.out"
data_coordinators = extract_numbers_by_coordinator(filename_A1E2)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models(filename_A1E2)
models_mean_values = calculate_column_means(data_models)
# Print results
print("Coordinators All")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models All")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")

# Recall results for A1, E1 without attack - Voting # Ignorar 3 y 4
print("Results for models Analysis 1, Experiment 2 - Without attack")
data_coordinators = extract_numbers_by_coordinator_voting(filename_A1E2)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models_voting(filename_A1E2)
models_mean_values = calculate_column_means(data_models)

# Print results
print("Coordinators Voting")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models Voting")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
# Out:
# Results for coordinators Analysis 1, Experiment 2 - Without attack
# Coordinators All
# Models All
# Results for models Analysis 1, Experiment 2 - Without attack
# Coordinators Voting
# Models Voting

# %%
# Recall results for A1, E2 with attack A1: attack a random ADS each round

print("Results for coordinators Analysis 1, Experiment 2 - A1: attack a random ADS each round")
filename_A1E2_A1 = "nohup_EXPERIMENTS_mainBoth_SameDataset_v2-adversarial_recall_adversarialA1.out"
data_coordinators = extract_numbers_by_coordinator(filename_A1E2_A1)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models(filename_A1E2_A1)
models_mean_values = calculate_column_means(data_models)
# Print results
print("Coordinators All")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models All")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")

# Recall results for A1, E1 without attack - Voting # Ignorar 3 y 4
print("Results for models Analysis 1, Experiment 2 - A1: attack a random ADS each round")
data_coordinators = extract_numbers_by_coordinator_voting(filename_A1E2_A1)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models_voting(filename_A1E2_A1)
models_mean_values = calculate_column_means(data_models)

# Print results
print("Coordinators Voting")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models Voting")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
# Out:
# Results for coordinators Analysis 1, Experiment 2 - A1: attack a random ADS each round
# Coordinators All
# Coordinator 1: Column-wise Means = 0.6830605926581159
# Coordinator 2: Column-wise Means = 0.6699650502402796
# Coordinator 3: Column-wise Means = 0.8130187854958497
# Coordinator 4: Column-wise Means = 0.7542813455657492
# Coordinator 5: Column-wise Means = 0.6630843162953255
# Models All
# Coordinator 1: Column-wise Means = [0.8449264896890141, 0.7440074906367041, 0.7923220973782772, 0.8205992509363296, 0.8155430711610487]
# Coordinator 2: Column-wise Means = [0.8742169603774013, 0.8176303026512546, 0.8739730155390922, 0.883968523814668, 0.8825797849658004]
# Coordinator 3: Column-wise Means = [0.9293973157761459, 0.8228611716009302, 0.8838164306142291, 0.8893514859647826, 0.8851952194406382]
# Coordinator 4: Column-wise Means = [0.9215826791592808, 0.8167077934261623, 0.8702829786387232, 0.8830460145895758, 0.8862698218661693]
# Coordinator 5: Column-wise Means = [0.9215826791592808, 0.8176303026512546, 0.8730505063139999, 0.8795080708896457, 0.8835022941908925]
# Results for models Analysis 1, Experiment 2 - A1: attack a random ADS each round
# Coordinators Voting
# Coordinator 1: Column-wise Means = 0.6830605926581159
# Coordinator 2: Column-wise Means = 0.6699650502402796
# Coordinator 3: Column-wise Means = 0.8130187854958497
# Coordinator 4: Column-wise Means = 0.7542813455657492
# Coordinator 5: Column-wise Means = 0.6630843162953255
# Models Voting
# Coordinator 1: Column-wise Means = [0.8449264896890141, 0.7440074906367041, 0.7923220973782772, 0.8205992509363296, 0.8155430711610487]
# Coordinator 2: Column-wise Means = [0.8742169603774013, 0.8176303026512546, 0.8739730155390922, 0.883968523814668, 0.8825797849658004]
# Coordinator 3: Column-wise Means = [0.9293973157761459, 0.8228611716009302, 0.8838164306142291, 0.8893514859647826, 0.8851952194406382]
# Coordinator 4: Column-wise Means = [0.9215826791592808, 0.8167077934261623, 0.8702829786387232, 0.8830460145895758, 0.8862698218661693]
# Coordinator 5: Column-wise Means = [0.9215826791592808, 0.8176303026512546, 0.8730505063139999, 0.8795080708896457, 0.8835022941908925]

# %%
# Recall results for A1, E2 with attack A2: attack the weakest (RF) ADS each round

print("Results for coordinators Analysis 1, Experiment 2 - A2: attack the weakest (RF) ADS each round")
filename_A1E2_A2 = "nohup_EXPERIMENTS_mainBoth_SameDataset_v2-adversarial_recall_adversarialA2.out"
data_coordinators = extract_numbers_by_coordinator(filename_A1E2_A2)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models(filename_A1E2_A2)
models_mean_values = calculate_column_means(data_models)
# Print results
print("Coordinators All")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models All")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")

# Recall results for A1, E1 without attack - Voting # Ignorar 3 y 4
print("Results for models Analysis 1, Experiment 2 - A2: attack the weakest (RF) ADS each round")
data_coordinators = extract_numbers_by_coordinator_voting(filename_A1E2_A2)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models_voting(filename_A1E2_A2)
models_mean_values = calculate_column_means(data_models)

# Print results
print("Coordinators Voting")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models Voting")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
# Out:
# Results for coordinators Analysis 1, Experiment 2 - A2: attack the weakest (RF) ADS each round
# Coordinators All
# Coordinator 1: Column-wise Means = 0.6830605926581159
# Coordinator 2: Column-wise Means = 0.6699650502402796
# Coordinator 3: Column-wise Means = 0.7518130187854959
# Coordinator 4: Column-wise Means = 0.7260594145915247
# Coordinator 5: Column-wise Means = 0.6839012669287898
# Models All
# Coordinator 1: Column-wise Means = [0.8644194756554308, 0.7440074906367041, 0.7923220973782772, 0.8099825786878487, 0.8155430711610487]
# Coordinator 2: Column-wise Means = [0.914897457911405, 0.8176303026512546, 0.8739730155390922, 0.8285318999342269, 0.8825797849658004]
# Coordinator 3: Column-wise Means = [0.9218212521108262, 0.8228611716009302, 0.8847389398393213, 0.9066497847556343, 0.8861177286657305]
# Coordinator 4: Column-wise Means = [0.9158199671364973, 0.81578528420107, 0.8748955247641845, 0.8836312990630539, 0.8862698218661693]
# Coordinator 5: Column-wise Means = [0.9158199671364973, 0.8176303026512546, 0.8795080708896457, 0.8801494049126362, 0.8871923310912616]
# Results for models Analysis 1, Experiment 2 - A2: attack the weakest (RF) ADS each round
# Coordinators Voting
# Coordinator 1: Column-wise Means = 0.6830605926581159
# Coordinator 2: Column-wise Means = 0.6699650502402796
# Coordinator 3: Column-wise Means = 0.7518130187854959
# Coordinator 4: Column-wise Means = 0.7260594145915247
# Coordinator 5: Column-wise Means = 0.6839012669287898
# Models Voting
# Coordinator 1: Column-wise Means = [0.8644194756554308, 0.7440074906367041, 0.7923220973782772, 0.8099825786878487, 0.8155430711610487]
# Coordinator 2: Column-wise Means = [0.914897457911405, 0.8176303026512546, 0.8739730155390922, 0.8285318999342269, 0.8825797849658004]
# Coordinator 3: Column-wise Means = [0.9218212521108262, 0.8228611716009302, 0.8847389398393213, 0.9066497847556343, 0.8861177286657305]
# Coordinator 4: Column-wise Means = [0.9158199671364973, 0.81578528420107, 0.8748955247641845, 0.8836312990630539, 0.8862698218661693]
# Coordinator 5: Column-wise Means = [0.9158199671364973, 0.8176303026512546, 0.8795080708896457, 0.8801494049126362, 0.8871923310912616]

# %%
# Recall results for A1, E2 with attack A3: attack 1/3 of ADS each round

print("Results for coordinators Analysis 1, Experiment 2 - A3: attack 1/3 of ADS each round")
filename_A1E2_A3 = "nohup_EXPERIMENTS_mainBoth_SameDataset_v2-adversarial_recall_adversarialA3.out"
data_coordinators = extract_numbers_by_coordinator(filename_A1E2_A3)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models(filename_A1E2_A3)
models_mean_values = calculate_column_means(data_models)
# Print results
print("Coordinators All")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models All")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")

# Recall results for A1, E1 without attack - Voting # Ignorar 3 y 4
print("Results for models Analysis 1, Experiment 2 - A3: attack 1/3 of ADS each round")
data_coordinators = extract_numbers_by_coordinator_voting(filename_A1E2_A3)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models_voting(filename_A1E2_A3)
models_mean_values = calculate_column_means(data_models)

# Print results
print("Coordinators Voting")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models Voting")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
# Out:
# Results for coordinators Analysis 1, Experiment 2 - A3: attack 1/3 of ADS each round
# Coordinators All
# Coordinator 1: Column-wise Means = 0.684608580274215
# Coordinator 2: Column-wise Means = 0.6722586282219309
# Coordinator 3: Column-wise Means = 0.8740498034076016
# Coordinator 4: Column-wise Means = 0.8341852337265181
# Coordinator 5: Column-wise Means = 0.8322411533420708
# Models All
# Coordinator 1: Column-wise Means = [0.8644194756554308, 0.7019037132895298, 0.7517427270192397, 0.8205992509363296, 0.7798694474036049]
# Coordinator 2: Column-wise Means = [0.914897457911405, 0.7606098750311855, 0.8085062711210904, 0.883968523814668, 0.8394003311333378]
# Coordinator 3: Column-wise Means = [0.9227437613359184, 0.8252924791086351, 0.8730049801637545, 0.8930415228651516, 0.8935350721701696]
# Coordinator 4: Column-wise Means = [0.9158199671364973, 0.8220815396302861, 0.8664927829830337, 0.8848910330397604, 0.8902338144677977]
# Coordinator 5: Column-wise Means = [0.9176649855866817, 0.820688781970119, 0.869278298303368, 0.8850431262401992, 0.8923229509580485]
# Results for models Analysis 1, Experiment 2 - A3: attack 1/3 of ADS each round
# Coordinators Voting
# Coordinator 1: Column-wise Means = 0.684608580274215
# Coordinator 2: Column-wise Means = 0.6722586282219309
# Coordinator 3: Column-wise Means = 0.8740498034076016
# Coordinator 4: Column-wise Means = 0.8341852337265181
# Coordinator 5: Column-wise Means = 0.8322411533420708
# Models Voting
# Coordinator 1: Column-wise Means = [0.8644194756554308, 0.7019037132895298, 0.7517427270192397, 0.8205992509363296, 0.7798694474036049]
# Coordinator 2: Column-wise Means = [0.914897457911405, 0.7606098750311855, 0.8085062711210904, 0.883968523814668, 0.8394003311333378]
# Coordinator 3: Column-wise Means = [0.9227437613359184, 0.8252924791086351, 0.8730049801637545, 0.8930415228651516, 0.8935350721701696]
# Coordinator 4: Column-wise Means = [0.9158199671364973, 0.8220815396302861, 0.8664927829830337, 0.8848910330397604, 0.8902338144677977]
# Coordinator 5: Column-wise Means = [0.9176649855866817, 0.820688781970119, 0.869278298303368, 0.8850431262401992, 0.8923229509580485]

# %%
# Recall results for A1, E2 with attack A4: attack all of ADS each round

print("Results for coordinators Analysis 1, Experiment 2 - A4: attack all of ADS each round")
filename_A1E2_A4 = "nohup_EXPERIMENTS_mainBoth_SameDataset_v2-adversarial_recall_adversarialA4.out"
data_coordinators = extract_numbers_by_coordinator(filename_A1E2_A4)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models(filename_A1E2_A4)
models_mean_values = calculate_column_means(data_models)
# Print results
print("Coordinators All")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models All")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")

print(f"Overall mean values for models: {calculate_overall_column_mean(models_mean_values)}")
# Recall results for A1, E1 without attack - Voting # Ignorar 3 y 4
print("Results for models Analysis 1, Experiment 2 - A4: attack all of ADS each round")
data_coordinators = extract_numbers_by_coordinator_voting(filename_A1E2_A4)
coordinators_mean_values = calculate_means(data_coordinators)

data_models = extract_numbers_by_coordinator_models_voting(filename_A1E2_A4)
models_mean_values = calculate_column_means(data_models)

# Print results
print("Coordinators Voting")
for coordinator, means in sorted(coordinators_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
print("Models Voting")
for coordinator, means in sorted(models_mean_values.items()):
    print(f"Coordinator {coordinator}: Column-wise Means = {means}")
# Out:
# Results for coordinators Analysis 1, Experiment 2 - A4: attack all of ADS each round
# Coordinators All
# Coordinator 1: Column-wise Means = 0.684608580274215
# Coordinator 2: Column-wise Means = 0.6722586282219309
# Coordinator 3: Column-wise Means = 0.864700742682394
# Coordinator 4: Column-wise Means = 0.864700742682394
# Coordinator 5: Column-wise Means = 0.827304499781564
# Models All
# Coordinator 1: Column-wise Means = [0.8449264896890141, 0.7019037132895298, 0.7517427270192397, 0.8099825786878487, 0.7798694474036049]
# Coordinator 2: Column-wise Means = [0.8742169603774013, 0.7606098750311855, 0.8085062711210904, 0.8285318999342269, 0.8394003311333378]
# Coordinator 3: Column-wise Means = [0.9300936946062295, 0.8252924791086351, 0.8778796319743395, 0.9038642694353001, 0.8935350721701696]
# Coordinator 4: Column-wise Means = [0.9222790579893644, 0.8213851608002025, 0.869278298303368, 0.8836312990630539, 0.8923229509580485]
# Coordinator 5: Column-wise Means = [0.9215826791592808, 0.8227779184603696, 0.8706710559635351, 0.8836312990630539, 0.8923229509580485]
# Overall mean values for models: [0.898619776364258, 0.7863938293379844, 0.8356155968763146, 0.8619282692366965, 0.8594901505246417]
# Results for models Analysis 1, Experiment 2 - A4: attack all of ADS each round
# Coordinators Voting
# Coordinator 1: Column-wise Means = 0.684608580274215
# Coordinator 2: Column-wise Means = 0.6722586282219309
# Coordinator 3: Column-wise Means = 0.864700742682394
# Coordinator 4: Column-wise Means = 0.864700742682394
# Coordinator 5: Column-wise Means = 0.827304499781564
# Models Voting
# Coordinator 1: Column-wise Means = [0.8449264896890141, 0.7019037132895298, 0.7517427270192397, 0.8099825786878487, 0.7798694474036049]
# Coordinator 2: Column-wise Means = [0.8742169603774013, 0.7606098750311855, 0.8085062711210904, 0.8285318999342269, 0.8394003311333378]
# Coordinator 3: Column-wise Means = [0.9300936946062295, 0.8252924791086351, 0.8778796319743395, 0.9038642694353001, 0.8935350721701696]
# Coordinator 4: Column-wise Means = [0.9222790579893644, 0.8213851608002025, 0.869278298303368, 0.8836312990630539, 0.8923229509580485]
# Coordinator 5: Column-wise Means = [0.9215826791592808, 0.8227779184603696, 0.8706710559635351, 0.8836312990630539, 0.8923229509580485]
